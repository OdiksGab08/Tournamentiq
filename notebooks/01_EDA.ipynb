# %%
import sys
from pathlib import Path

# Allow notebooks to import src
sys.path.append(str(Path.cwd().parent))

from src.shared.paths import MATCHES_DATA

import pandas as pd

df = pd.read_csv(MATCHES_DATA)

print(df.shape)
df.head()
# Out:
# (417, 8)
#    match_id                  date                    competition  \
# 0    554740  2026-01-28T22:00:00Z  Campeonato Brasileiro Série A
# 1    554744  2026-01-28T22:00:00Z  Campeonato Brasileiro Série A
# 2    554746  2026-01-28T22:00:00Z  Campeonato Brasileiro Série A
# 3    554749  2026-01-28T22:00:00Z  Campeonato Brasileiro Série A
# 4    554745  2026-01-28T22:30:00Z  Campeonato Brasileiro Série A
#
#           home_team      away_team  home_score  away_score    status
# 0        CA Mineiro   SE Palmeiras           2           2  FINISHED
# 1      Coritiba FBC  RB Bragantino           0           1  FINISHED
# 2  SC Internacional  CA Paranaense           0           1  FINISHED
# 3        EC Vitória  Clube do Remo           2           0  FINISHED
# 4     Fluminense FC    Grêmio FBPA           2           1  FINISHED
