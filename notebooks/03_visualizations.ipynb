# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.shared.data_loader import load_matches
from src.eda.visualization import (
    plot_match_results,
    plot_goal_distribution,
    plot_top_teams,
)

df = load_matches()

plot_match_results(df)

plot_goal_distribution(df)

plot_top_teams(df)

print("Charts generated successfully.")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 2026-07-05 14:01:39,968 | INFO | WorldCupPredictor | Creating match result chart...
# 2026-07-05 14:01:46,929 | INFO | WorldCupPredictor | Creating goal distribution...
# 2026-07-05 14:01:49,911 | INFO | WorldCupPredictor | Creating team frequency chart...
# Charts generated successfully.
