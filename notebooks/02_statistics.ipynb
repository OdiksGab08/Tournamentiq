# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.shared.data_loader import load_matches
from src.eda.statistics import (
    football_statistics,
    print_statistics,
)

df = load_matches()

stats = football_statistics(df)

print_statistics(stats)
# Out:
# 2026-07-05 13:57:49,664 | INFO | WorldCupPredictor | ============================================================
# 2026-07-05 13:57:49,666 | INFO | WorldCupPredictor | Computing Football Statistics
# 2026-07-05 13:57:49,673 | INFO | WorldCupPredictor | ============================================================
# 2026-07-05 13:57:50,030 | INFO | WorldCupPredictor | Football statistics completed.
# ...
# FOOTBALL STATISTICS
# ...
# total_matches            : 417
# total_goals              : 1269
# average_goals            : 3.04
# median_goals             : 3.0
# maximum_goals            : 10
# minimum_goals            : 0
# home_wins                : 203
# away_wins                : 120
# draws                    : 94
# home_win_rate            : 0.487
# away_win_rate            : 0.288
# draw_rate                : 0.225
# competitions             : 3
# unique_teams             : 80
# ...
