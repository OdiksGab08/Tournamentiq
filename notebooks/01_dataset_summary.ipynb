# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.shared.data_loader import load_matches
from src.eda.summary import (
    dataset_summary,
    print_summary,
)

df = load_matches()

summary = dataset_summary(df)

print_summary(summary)
# Out:
# 2026-07-05 13:52:44,885 | INFO | WorldCupPredictor | ============================================================
# 2026-07-05 13:52:44,892 | INFO | WorldCupPredictor | Generating Dataset Summary
# 2026-07-05 13:52:44,892 | INFO | WorldCupPredictor | ============================================================
# 2026-07-05 13:52:45,095 | INFO | WorldCupPredictor | Dataset Summary Generated.
# ============================================================
# DATASET SUMMARY
# ============================================================
# rows                : 417
# columns             : 8
# memory_mb           : 0.06
# duplicate_rows      : 0
# missing_values      : 0
# column_names        : ['match_id', 'date', 'competition', 'home_team', 'away_team', 'home_score', 'away_score', 'status']
# data_types          : {'match_id': 'int64', 'date': 'str', 'competition': 'str', 'home_team': 'str', 'away_team': 'str', 'home_score': 'int64', 'away_score': 'int64', 'status': 'str'}
# date_range          : ('2024-06-14', '2026-05-31')
# unique_teams        : 80
# competitions        : 3
# ============================================================
