# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.shared.data_loader import load_matches
from src.features.base import create_base_features

df = load_matches()

features = create_base_features(df)

print(features.shape)

features.head()
# Out:
# 2026-07-05 14:18:47,841 | INFO | WorldCupPredictor | ============================================================
# 2026-07-05 14:18:47,844 | INFO | WorldCupPredictor | Generating Base Features
# 2026-07-05 14:18:47,846 | INFO | WorldCupPredictor | ============================================================
# 2026-07-05 14:18:48,042 | INFO | WorldCupPredictor | Base features created successfully (23 columns).
# (417, 23)
#    match_id                      date                    competition  \
# 0    554740 2026-01-28 22:00:00+00:00  Campeonato Brasileiro Série A
# 1    554744 2026-01-28 22:00:00+00:00  Campeonato Brasileiro Série A
# 2    554746 2026-01-28 22:00:00+00:00  Campeonato Brasileiro Série A
# 3    554749 2026-01-28 22:00:00+00:00  Campeonato Brasileiro Série A
# 4    554745 2026-01-28 22:30:00+00:00  Campeonato Brasileiro Série A
#
#           home_team      away_team  home_score  away_score    status  \
# ...
