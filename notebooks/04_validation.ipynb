# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.shared.data_loader import load_matches
from src.eda.validation import (
    validate_dataset,
    print_validation,
)

df = load_matches()

report = validate_dataset(df)

print_validation(report)
# Out:
# 2026-07-05 14:05:12,511 | INFO | WorldCupPredictor | ============================================================
# 2026-07-05 14:05:12,515 | INFO | WorldCupPredictor | Running Dataset Validation
# 2026-07-05 14:05:12,516 | INFO | WorldCupPredictor | ============================================================
# 2026-07-05 14:05:12,572 | INFO | WorldCupPredictor | Validation completed.
# ============================================================
# DATA VALIDATION REPORT
# ============================================================
# rows                          : 417
# duplicate_rows                : 0
# missing_values                : {'match_id': 0, 'date': 0, 'competition': 0, 'home_team': 0, 'away_team': 0, 'home_score': 0, 'away_score': 0, 'status': 0}
# negative_scores               : 0
# duplicate_match_ids           : 0
# invalid_dates                 : 0
# missing_home_team             : 0
# missing_away_team             : 0
# ============================================================
